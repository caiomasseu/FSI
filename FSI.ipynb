# %% [markdown]
# <a href="https://colab.research.google.com/github/caiomasseu/FSI/blob/master/FSI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
DigiDB = pd.read_csv("DigiDB_digimonlist.csv",index_col=0)
DigiDB
# Out:
#                   Digimon Stage     Type  ... Lv50 Def  Lv50 Int  Lv50 Spd
# Number                                    ...
# 1                 Kuramon  Baby     Free  ...       69        68        95
# 2                 Pabumon  Baby     Free  ...       76        69        68
# 3                 Punimon  Baby     Free  ...       87        50        75
# 4                 Botamon  Baby     Free  ...       95        76        61
# 5                 Poyomon  Baby     Free  ...       59        95        86
# ...                   ...   ...      ...  ...      ...       ...       ...
# 245            Valkyrimon  Mega     Free  ...      129       129       168
# 246       ShineGreymon BM  Mega  Vaccine  ...      104        84       168
# 247     MirageGaogamon BM  Mega     Data  ...      104       158       174
# 248            Ravemon BM  Mega  Vaccine  ...      139       144       213
# 249            Rosemon BM  Mega     Data  ...      139       159       143
#
# [249 rows x 12 columns]

# %%
DigiDB.Attribute.describe()
# Out:
# count      249
# unique       9
# top       Dark
# freq        37
# Name: Attribute, dtype: object

# %%
DigiDB.Attribute.value_counts().plot.pie()

# %%
DigiDB.Attribute.value_counts().plot.bar()

# %%
DigiDB["Lv 50 HP"].value_counts().sort_index().head(20).plot.bar()

# %%
DigiDB["Lv 50 HP"].value_counts().sort_index().plot.area()

# %%
DigiDB["Lv 50 HP"].plot.hist()

# %%
DigiDB[DigiDB["Lv 50 HP"]<10000].plot.scatter(x='Attribute',y='Lv 50 HP')

# %%
sns.countplot(x='Attribute', data=DigiDB)

# %%
sns.catplot(x="Stage",col='Attribute', kind="count", data=DigiDB)

# %%
sns.catplot(x="Type",col='Attribute', kind="count", data=DigiDB)
